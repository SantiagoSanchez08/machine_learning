# %% [markdown]
# # Let's start on the basics. Variables and arrays

# %% [markdown]
# ### First, import some libraries

# %%
import numpy as np

# %%
N=10
array_1 = np_ # Create an array of N values
array_2 = _ # Create an array of random int values
            # with the same lenght as array_1

_ # print both array_1 and array_2
_ # print both array_1 and array_2 shapes
_ # print summation of array_1 and array_2
# Out:
# ''

# %%
_ # Replace the value of array_1 in pos 3 by 70
_ # Print summation again

# %%
_ # Apply element-wise multiplication among array_1 and array_2
_ # Print results

# %% [markdown]
# # Playing with some images! Introduction to OpenCV
#
# Download the image [lena.jpg](https://drive.google.com/file/d/1gH5sJN__2g7f9ndLhLvTECdOBJIGUbg_/view) before getting started!

# %% [markdown]
# ### First, let's mount Google drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Import some libraries

# %%
# !pip install nombre_libreria
# !python -m install nombre_libreria
# !py -3 -m pip install
# Out:
# ERROR: Could not find a version that satisfies the requirement nombre_libreria (from versions: none)
# ERROR: No matching distribution found for nombre_libreria
# /usr/bin/python3: No module named install

# %%
# Import some libraries
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load an image using OpenCV

# %%
# Loading a color image
img = cv2.imread('/content/drive/MyDrive/Machine Learning/Material/lena.jpg')

from google.colab.patches import cv2_imshow
cv2_imshow(img)
#plt.imshow(img) # plots an image
# Out:
# <PIL.Image.Image image mode=RGB size=400x300>

# %% [markdown]
# ### Let's play with the data

# %%
# Printing the image shape (size of the image)
img.shape
# Out:
# (300, 400, 3)

# %%
# Looking through the image...
# print among image indexes
pixel_value = img[100,150]
print("pixel value at [100,150]:",pixel_value)
print("Ejemplo: mostrar los pixeles que estan entre el rango de 100 a 105 y ña columna 150 a 155")
for row in range(100,105):
  for col in range(150,155):
    print(f"pixel value ar [{row},{col}]:{img[row,col]}")
# Out:
# pixel value at [100,150]: [ 63  79 145]
# Ejemplo: mostrar los pixeles que estan entre el rango de 100 a 105 y ña columna 150 a 155
# pixel value ar [100,150]:[ 63  79 145]
# pixel value ar [100,151]:[ 62  79 146]
# pixel value ar [100,152]:[ 62  67 128]
# pixel value ar [100,153]:[ 66  69 130]
# pixel value ar [100,154]:[ 98  99 159]
# pixel value ar [101,150]:[ 60  76 143]
# pixel value ar [101,151]:[ 63  79 148]
# pixel value ar [101,152]:[ 61  66 127]
# pixel value ar [101,153]:[ 69  74 135]
# pixel value ar [101,154]:[ 51  56 117]
# pixel value ar [102,150]:[ 50  67 134]
# pixel value ar [102,151]:[ 48  66 137]
# pixel value ar [102,152]:[ 55  65 125]
# pixel value ar [102,153]:[ 36  45 108]
# pixel value ar [102,154]:[ 51  60 123]
# pixel value ar [103,150]:[ 47  63 132]
# pixel value ar [103,151]:[ 39  57 128]
# pixel value ar [103,152]:[ 59  70 130]
# pixel value ar [103,153]:[ 54  65 127]
# pixel value ar [103,154]:[ 59  71 135]
# pixel value ar [104,150]:[ 52  60 120]
# pixel value ar [104,151]:[ 39  47 107]
# pixel value ar [104,152]:[ 54  69 141]
# pixel value ar [104,153]:[ 57  76 151]
# pixel value ar [104,154]:[ 72  94 172]

# %%
# Changing its channels values!
img = cv2.imread('/content/drive/MyDrive/Machine Learning/Material/lena.jpg',1)
cv2_imshow(img)
 # Voila!
# Out:
# <PIL.Image.Image image mode=RGB size=400x300>

# %% [markdown]
# ### Load an image in grayscale

# %%
# Loading a color image in grayscale
img_gray = cv2.imread('/content/drive/MyDrive/Machine Learning/Material/lena.jpg',0)
cv2_imshow(img_gray)
# Out:
# <PIL.Image.Image image mode=L size=400x300>

# %% [markdown]
# ### Play with the image

# %%
# Printing the image shape
print(img.shape)
# Out:
# (300, 400, 3)

# %%
# Regarding through the image... Again
img = cv2.imread('/content/drive/MyDrive/Machine Learning/Material/lena.jpg',0)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=L size=400x300>

# %%
print(img.shape)
# Out:
# (300, 400)

# %% [markdown]
# ### Going further

# %%
# Messing everything around.
img = cv2.imread('/content/drive/MyDrive/Machine Learning/Material/lena.jpg', 1)
img[:, :, 0] = 255
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=400x300>

# %%
print (img[0:10, 0:10])
# Out:
# [[[255   6   0]
#   [255  10  21]
#   [255   0  15]
#   [255   7   7]
#   [255   2   0]
#   [255   0   8]
#   [255   0  13]
#   [255   7   4]
#   [255   5   0]
#   [255   6   0]]
#
#  [[255   8  18]
#   [255  49  91]
#   [255  48 102]
#   [255  69 106]
#   [255  64  95]
#   [255  57 106]
#   [255  57 109]
#   [255  54  88]
#   [255  60 115]
#   [255  60 116]]
#
#  [[255   0  15]
#   [255  54 107]
#   [255  56 122]
#   [255  63 114]
#   [255  55 104]
#   [255  57 125]
#   [255  60 131]
#   [255  55 108]
#   [255  57 121]
#   [255  53 117]]
#
#  [[255   6   5]
#   [255  68 104]
#   [255  63 114]
#   [255  63 100]
#   [255  55  93]
#   [255  58 116]
#   [255  64 123]
#   [255  64 106]
#   [255  63 105]
#   [255  60 101]]
#
#  [[255   2   0]
#   [255  58  88]
#   [255  55 104]
#   [255  66 104]
#   [255  66 103]
#   [255  59 116]
#   [255  56 114]
#   [255  61  99]
#   [255  50 110]
#   [255  51 109]]
#
#  [[255   0  11]
#   [255  58 107]
#   [255  53 120]
#   [255  66 124]
#   [255  70 127]
#   [255  58 132]
#   [255  52 126]
#   [255  63 117]
#   [255  53 116]
#   [255  55 116]]
#
#  [[255   0  12]
#   [255  57 110]
#   [255  45 116]
#   [255  51 110]
#   [255  55 113]
#   [255  45 119]
#   [255  43 114]
#   [255  61 110]
#   [255  58 107]
#   [255  60 108]]
#
#  [[255   1   0]
#   [255  68 103]
#   [255  60 113]
#   [255  63 104]
#   [255  68 105]
#   [255  62 115]
#   [255  59 108]
#   [255  73 101]
#   [255  59 118]
#   [255  60 116]]
#
#  [[255   4   0]
#   [255  59 118]
#   [255  56 120]
#   [255  62 103]
#   [255  54 113]
#   [255  54 115]
#   [255  58 106]
#   [255  56 114]
#   [255  60 111]
#   [255  58 111]]
#
#  [[255   4   0]
#   [255  59 118]
#   [255  56 120]
#   [255  62 103]
#   [255  54 113]
#   [255  54 115]
#   [255  58 106]
#   [255  56 114]
#   [255  56 107]
#   [255  54 107]]]

# %%
# Playing with image intensities
img_gray = cv2.imread( _ )

for r in _  :  # Go through rows
  for c in _ : # Go through cols
    if _ : # Create a simple condition
      _ # Do something

plt.imshow(img_gray, _ )

# %% [markdown]
# ### Save an image using OpenCV

# %%
cv2.imwrite('newlena.png',img_gray)
# Out:
# True

# %% [markdown]
# ### Crop the image - taking regions of interest (ROI)

# %%
# Extract some ROI
roi = img[100:200,180:280]
cv2_imshow(roi)
# Out:
# <PIL.Image.Image image mode=RGB size=100x100>

# %%
img_gray[ _ , _ ] = roi
plt.imshow(img_gray, _ )

# %% [markdown]
# ## Load an image using pillow (PIL)

# %%
from PIL import Image

# %%
# Loading a color image
img = Image.open( _ )
plt.imshow(img) # plots an image
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py in open(fp, mode, formats)
#    3230     try:
# -> 3231         fp.seek(0)
#    3232     except (AttributeError, io.UnsupportedOperation):
#
# AttributeError: 'bool' object has no attribute 'seek'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-6b79434991a1> in <cell line: 2>()
#       1 # Loading a color image
# ----> 2 img = Image.open( _ )
#       3 plt.imshow(img) # plots an image
#
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py in open(fp, mode, formats)
#    3231         fp.seek(0)
#    3232     except (AttributeError, io.UnsupportedOperation):
# -> 3233         fp = io.BytesIO(fp.read())
#    3234         exclusive_fp = True
#    3235
#
# AttributeError: 'bool' object has no attribute 'read'

# %%
print (img[:10, :10]) ## Error. This is not an array

# %%
img = np.asarray( _ ) ## Convert to an array
print (img[ _ , _ ]) ## Now it works!
print (img.shape)

# %% [markdown]
# ### Load the image in grayscale

# %%
img = Image.open( _ ).convert("L")
plt.imshow(img, _ ) # plots an image
